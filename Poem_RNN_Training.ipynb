# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file

from functools import partial
from bayes_opt import BayesianOptimization

import numpy as np
import random
import sys
import os
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Reading dataset

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read().lower().split('\n')
poem_list = []
raw_text = ''
for j in range(len(text) + 1):
    if j == len(text):
        poem_list.append(raw_text)
    elif text[j] == '':
        if raw_text != '':
            poem_list.append(raw_text)
        raw_text = ''
        continue
    elif text[j][-1].isdigit():
        continue
    else:
        subsentence = text[j] + '\n'
        raw_text += subsentence  
print('Number of poems:', len(poem_list))
# Out:
# Number of poems: 154

# %% [markdown]
# ## Create Sequences

# %%
# organize into sequences of characters
def create_sequence(raw_text, length, step):
    sequences = []
    next_chars = []
    for i in range(0, len(raw_text) - length, step):
        # select sequence of tokens
        seq = raw_text[i:i + length]
        # store
        sequences.append(seq)
        next_chars.append(raw_text[i + length])
    return sequences, next_chars

# %%
length = 40
step = 1
sequences = []
next_chars = []
for poem in poem_list:
    sub_sequences, sub_next_chars = create_sequence(poem, length, step)
    sequences += sub_sequences
    next_chars += sub_next_chars
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 88130

# %% [markdown]
# ## Character Mappings and Inverse Mappings

# %%
poem_string = "".join(poem_list)
chars = sorted(list(set(poem_string)))
char_index_map = dict((c, i) for i, c in enumerate(chars))
index_char_map = dict((i, c) for i, c in enumerate(chars))
vocab_size = len(char_index_map)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 38

# %% [markdown]
# ## Vectorization

# %%
X = np.zeros((len(sequences), length, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sequences):
    for t, char in enumerate(sentence):
        X[i, t, char_index_map[char]] = 1
    y[i, char_index_map[next_chars[i]]] = 1

# %% [markdown]
# ## Build the RNN Training Model

# %%
import warnings
warnings.filterwarnings('ignore')
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(length, len(chars))))
model.add(Dense(len(chars))) 
model.add(Activation('softmax'))

model.summary()   

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# Build model...
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               85504
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                4902
# _________________________________________________________________
# activation_1 (Activation)    (None, 38)                0
# =================================================================
# Total params: 90,406
# Trainable params: 90,406
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## Sampling function (combining softmax with temperature)

# %%
def sample(preds, temperature):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Training the model with outputs

# %%
import warnings
warnings.filterwarnings('ignore')
for iteration in range(50):
    model.fit(X, y, batch_size=128, nb_epoch=10)

    for temperature in [1.5, 0.75, 0.25]:
        print()
        print('----- temperature parameter:', temperature)

        generated = ''
        sentence = "shall i compare thee to a summer's day?\n"
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        line_count = 0
        while (line_count <= 12):
            x = np.zeros((1, length, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_index_map[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = index_char_map[next_index]
            
            if next_char == '\n':
                line_count += 1

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 88130/88130 [==============================] - 132s 1ms/step - loss: 2.0384 - acc: 0.3983
# Epoch 2/10
# 88130/88130 [==============================] - 125s 1ms/step - loss: 1.6636 - acc: 0.4923
# Epoch 3/10
# 88130/88130 [==============================] - 131s 1ms/step - loss: 1.5536 - acc: 0.5225
# Epoch 4/10
# 88130/88130 [==============================] - 129s 1ms/step - loss: 1.4885 - acc: 0.5376
# Epoch 5/10
# 88130/88130 [==============================] - 132s 1ms/step - loss: 1.4412 - acc: 0.5523
# Epoch 6/10
# 88130/88130 [==============================] - 130s 1ms/step - loss: 1.4059 - acc: 0.5617
# Epoch 7/10
# 88130/88130 [==============================] - 130s 1ms/step - loss: 1.3805 - acc: 0.5679
# Epoch 8/10
# 88130/88130 [==============================] - 142s 2ms/step - loss: 1.3584 - acc: 0.5723
# Epoch 9/10
# 88130/88130 [==============================] - 140s 2ms/step - loss: 1.3404 - acc: 0.5782
# Epoch 10/10
# 88130/88130 [==============================] - 145s 2ms/step - loss: 1.3253 - acc: 0.5826
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# but ruck hringushed, wnore ffum now time
# liged's feased, but needered hermeause 'giif?
# thissuege your menutty, why haft yet again,
# why she elsengses nor make unthoughts use.
# o yet wrick invaisn strange chymfoine,
# and uf incfor hus, see i that fair,n maid.
# o latgonl was to tigs cont'talled abusigifl.capes aloode bkings,
# or andnow thy santain or ride,
# postrance paesessety misted divaekance erd
# of gentle gest all erryness edfor a im:
#   too fandcking to domior ablive.
# onger ad'ercuch?by arvi, witht, my spite?
# or think shall others' greativerch kest?
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# was to the caser rose hath her false hate life,
# that in loving thing to be store,
# my secder's seek is old doth all the part,
# when as their proud look to did fall thee repen,
# when thou thy dear heart in thee, and wells to far be bray,
# whose greet in my soul is from mine own yother,
# ond all our doth condow becomem to me,
# where every one thris thou not of brow,
# that thing your rude in thy heart to thought,
#   so thou hast pleasing on less where life,
# but than to a conting thought look a truly,
# and that good what in this good, but warder,
# to of growt'st that thou shourdst love will be injurily,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# why should i do should thine eyes to the state,
# and but that thou art all the strength show,
# that i will thou art all the strangely seeing,
# and that which his sweet false their shall show hate,
# and that i will be thine eyes that should should be stol's belong,
# and that thou hast but worth that which the store.
# when i so beauty straight from the strange,
# and that thou shouldst thing of thy self deceived,
# and that which hath that thou art all the strength,
# and that sweet false their sweet false so,
# and such sunstance than this most should should the beauty's world be stold,
# and that in thy self thy sweet self so blest,
# and that thou art must i am a seeming store,
#
# Epoch 1/10
# 88130/88130 [==============================] - 146s 2ms/step - loss: 1.3100 - acc: 0.5868
# Epoch 2/10
# 88130/88130 [==============================] - 150s 2ms/step - loss: 1.2999 - acc: 0.5888
# Epoch 3/10
# 88130/88130 [==============================] - 160s 2ms/step - loss: 1.2916 - acc: 0.5916
# Epoch 4/10
# 88130/88130 [==============================] - 165s 2ms/step - loss: 1.2806 - acc: 0.5946
# Epoch 5/10
# 88130/88130 [==============================] - 166s 2ms/step - loss: 1.2723 - acc: 0.5973
# Epoch 6/10
# 88130/88130 [==============================] - 176s 2ms/step - loss: 1.2629 - acc: 0.6012
# Epoch 7/10
# 88130/88130 [==============================] - 178s 2ms/step - loss: 1.2568 - acc: 0.6013
# Epoch 8/10
# 88130/88130 [==============================] - 191s 2ms/step - loss: 1.2490 - acc: 0.6043
# Epoch 9/10
# 88130/88130 [==============================] - 197s 2ms/step - loss: 1.2430 - acc: 0.6052
# Epoch 10/10
# 88130/88130 [==============================] - 208s 2ms/step - loss: 1.2371 - acc: 0.6079
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# tould 'tis too'ed-fair wouldst theys, i grtase,
# toofed, thy timoso-lund clearning layulh.
# in oursamitions is me yeabs, so figure:
# then one'' syher) thrusly diest worms life.
# and urwined dwell bavel'wturn's worth wriring ast.
# tastaypores all not lie eegring youth,
# in her' in a raben you most,
# thy holy,  hawars you darue mearfvowed liseignened;
# gat'st, and incmights men viston and wire,
#   may flise, and make make i, angry drass bive,
#   oih for tow
# ognsts your sold whots ford thus holglying,
#   by nillious nighteres, yenstklly gose,
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou that where yet thou shouldst his whine from my self'st so diress,
#   so the name than that farthe cannot strong,
# and in the basest alone, and they in thee.
#   to and for deleminded by thy time,
# whils i all i return come with your graces,
# that how one give to best and thou thy heart.
# oneous both where bord that what you wide,
# where thou thy heart's deep watken thiefd,
#   in cloud strong winge, and whem i have show,
# thou leisureled with thee that that the stelled.
#   then she grace of love's love removed one,
# where i may steal thy heart inwint and none?
# proftly your beauty besoeth speeds?
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o but thou beauty be thou shouldst my love,
# that which i that which i that thou art of thee.
#   thou whom thou that thou wound the living thee,
# thou wilt thou that is so fair where thou dost shame,
# when i see the truth that thou shouldst be strong,
# where thou shouldst my heart in the thought,
# and there thou steal thee i was should thee,
# when i sleeping on the beauty be straight,
# and that heaven the beauty that which find,
# which i that which i thou art me thee to thee,
#   thou art my heart in the time that in thee,
# when i then thou art the world will be thee,
# whilst he where thou dost beauty that show,
#
# Epoch 1/10
# 88130/88130 [==============================] - 214s 2ms/step - loss: 1.2311 - acc: 0.6086
# Epoch 2/10
# 88130/88130 [==============================] - 212s 2ms/step - loss: 1.2254 - acc: 0.6103
# Epoch 3/10
# 88130/88130 [==============================] - 221s 3ms/step - loss: 1.2196 - acc: 0.6128
# Epoch 4/10
# 88130/88130 [==============================] - 224s 3ms/step - loss: 1.2142 - acc: 0.6139
# Epoch 5/10
# 88130/88130 [==============================] - 229s 3ms/step - loss: 1.2099 - acc: 0.6154
# Epoch 6/10
# 88130/88130 [==============================] - 231s 3ms/step - loss: 1.2034 - acc: 0.6177
# Epoch 7/10
# 88130/88130 [==============================] - 237s 3ms/step - loss: 1.2010 - acc: 0.6156
# Epoch 8/10
# 88130/88130 [==============================] - 246s 3ms/step - loss: 1.1960 - acc: 0.6198
# Epoch 9/10
# 88130/88130 [==============================] - 243s 3ms/step - loss: 1.1900 - acc: 0.6214
# Epoch 10/10
# 88130/88130 [==============================] - 251s 3ms/step - loss: 1.1852 - acc: 0.6233
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# when leaking trues urivi sho ceave of hie,
# when wasel k'eysful natures after my wind,
# it '
# thee levow :rargth,ejw, you slave angi divan me xcanknot deturht,
# whatef vicyures of my wowards none in me subsior
# mytcep, rarge barer's saftiou foreflowedign,
# and bousty bress' to cuttens, each hate
# foundvatiencion of bleft,
# s't if spacks mus to back agamenn
# which wy one, yut her thtery then theith
# burgndhble my deserfly carve's name) invertion,
# will o'elun, bellatteous their pity-pounty.
# for   'tis muse canhope cries of most reuiranch'st dverest:
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o nor the world's child in pride some and riff.
# but sin by the story do all the bents so streemness,
# came thouch well to make the world to hea
# thy preased'st straight false obseprared,
# of their showlest and with heary bearom night,
#   where true whose false born the prease you,
# one heart's cure but no lease i have still due,
# will waste makes his shade not them so sfeep,
# to show the first to the moot,
# steal i thou cosess till mad, with pure on their scope,
# when thou wilt faired thee i founten than of heaven
# see he contracted lips no true doth far'st,
# to these in dead, therefore i hast when my veirs,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou art with the beauty the world deserved,
# and that the world will be from thee and sorrow,
# to linge on the world will be beloved weedness,
# when i am my love to make the world so show,
#   then i am the world doth my deserved.
#   then which i see the state thee with thee,
#   then i see the world's with the world for my see,
# for then my love and the world will be gone,
# and thee as the world's winged and with time,
# and make the mother's worth the world will be gint,
# when i am the world's sound the world be gone,
# which i that i have still the world with thee,
#   makes the world's with thee with thee are mine to thee,
#
# Epoch 1/10
# 88130/88130 [==============================] - 259s 3ms/step - loss: 1.1834 - acc: 0.6229
# Epoch 2/10
# 88130/88130 [==============================] - 276s 3ms/step - loss: 1.1781 - acc: 0.6259
# Epoch 3/10
# 88130/88130 [==============================] - 269s 3ms/step - loss: 1.1738 - acc: 0.6249
# Epoch 4/10
# 88130/88130 [==============================] - 275s 3ms/step - loss: 1.1709 - acc: 0.6263
# Epoch 5/10
# 88130/88130 [==============================] - 271s 3ms/step - loss: 1.1650 - acc: 0.6290
# Epoch 6/10
# 88130/88130 [==============================] - 286s 3ms/step - loss: 1.1602 - acc: 0.6287
# Epoch 7/10
# 88130/88130 [==============================] - 299s 3ms/step - loss: 1.1576 - acc: 0.6297
# Epoch 8/10
# 88130/88130 [==============================] - 288s 3ms/step - loss: 1.1554 - acc: 0.6321
# Epoch 9/10
# 88130/88130 [==============================] - 294s 3ms/step - loss: 1.1559 - acc: 0.6310
# Epoch 10/10
# 88130/88130 [==============================] - 304s 3ms/step - loss: 1.1497 - acc: 0.6336
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# weos that to shormwarding my blhats, or :
# and thoughtght blees with use fatrelant'es delave,
# but manneted our alace for, and our welds:
# of, my loud servased ojuger,
# by that gravity must hapebe, his fenram seedn
# vityvarm true mrulkfful rebel in from thyle,
# of noo's some fiemter suburner fows your weoawx doobsess fuld:
# that conspen centance, if dispatch mivence.
# mint periftion she mendarage muce,
# ahs dove wail him advape, hast re time.
# thy sot hackance and thy frrith tived of me,
#     o jecat) forger is coombs her, some louns, mine's emy frawalions of heav's e
# :ch, !utverual shaupowe (wit sweet loving pitcy?
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o that with my self thou to praise thee:
# the poet give my fair ranks thet they grief
# and speak will i from the wasch this from my heart,
# that a pity one shays that my mease thought,
# but then, which day my range hath night note.
#   and i art age my heart knows no new,
#   and i no lovers in as your pride thou bright in their make poor spent.
# nor the painting of my more too me,
#   for my love's sportured unstay of many,
# and the moring offend lives thou defence,
# now i am a wordanless compare thee anothers,
# subvert be a fair gentle date's truth,
# and such say thee for my self do not give.
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o nor them thou thy self thou this beauty,
# and thou shouldst thou that my self do not,
# and all thou art a former thee to me.
#   and then thou thy self thou art the fair brow,
# nor doth thy self thou art a first to showers,
# and thou thy self thou thy self thou shouldst to be.
#   and thou that thou deserve the fair beast,
# that thou thy self thou shouldst thou thy self dost thou desire,
# and thou art the forest things thee should his story.
#   then be the true blood the truth to thee,
#   and thou art the bounte of the better thee,
#   thou art the time that thou thy self shorn.
# and is this thy self the fores me belone.
#
# Epoch 1/10
# 88130/88130 [==============================] - 316s 4ms/step - loss: 1.1471 - acc: 0.6334
# Epoch 2/10
# 88130/88130 [==============================] - 330s 4ms/step - loss: 1.1448 - acc: 0.6349
# Epoch 3/10
# 88130/88130 [==============================] - 319s 4ms/step - loss: 1.1414 - acc: 0.6342
# Epoch 4/10
# 88130/88130 [==============================] - 317s 4ms/step - loss: 1.1347 - acc: 0.6370
# Epoch 5/10
# 88130/88130 [==============================] - 327s 4ms/step - loss: 1.1336 - acc: 0.6369
# Epoch 6/10
# 88130/88130 [==============================] - 323s 4ms/step - loss: 1.1323 - acc: 0.6357
# Epoch 7/10
# 88130/88130 [==============================] - 339s 4ms/step - loss: 1.1304 - acc: 0.6402
# Epoch 8/10
# 88130/88130 [==============================] - 330s 4ms/step - loss: 1.1249 - acc: 0.6402
# Epoch 9/10
# 88130/88130 [==============================] - 344s 4ms/step - loss: 1.1224 - acc: 0.6414
# Epoch 10/10
# 88130/88130 [==============================] - 361s 4ms/step - loss: 1.1180 - acc: 0.6411
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o seth you am, cannot thinusber worarcy-poing,
# and mack another anyivat themsel wasde'sty,
# one c!jowe but buds to time's content?
# now to be summs as that which ip it mo'r ow.
# that freckpt, oil did virtue from him wuke.
# the dearn ravespen to sleeing speak,
# comould unyess correcks and thrivel shxt.
# thou welt, you welts grooted moin takeraw,
# to torxur bho
# ith to kneling,
# she wan, luk, 'i host such artigh age with upin and,
# as in husband's love privant nege,
# and, by did my brongoks, thlir good engr:
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou cand'rin which be in my lays thy love,
# thy recordance eyes, of this thousest thy suvcryance thee wit
# have thy thence why this beauty's dear heart
# to divide to time's fair, upon the rank,
# that thou in my sake the bable thee i new,
# when i am more duly what in the wike to his gentless,
# that i am for her see thou art scarce pinceid-int
# thy self desire which bost on thy sweet shee.
# so your wintoken every one so to his fine,
# but success the time do not so composed strong,
# whose streams i smeled and the breath to thee doth ghquit,
# when i have should not be fair thou hast.
# the stredguenet a goldenct that i have show,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou thy self thou shouldst be thy breath
# a please the beauty of my heaven the time,
# that thy self alone, that your self thou art,
#   thou thy self thou shouldst be thy sweet strong,
# that thy self thou shouldst be a barren thee,
#   that in the looks, and in thy self thou art.
# but thou thy self thou shouldst be blame,
# and thou thy self thou steal thee thy sweet strange,
# and the streaths being fading thy strenge,
# which thou thy self thou steal thee in thy brow,
# for thy self thou thy self thou in the store,
# and such so that i have i fear the store,
# since what is the world's dumb the stier,
#
# Epoch 1/10
# 88130/88130 [==============================] - 396s 4ms/step - loss: 1.1164 - acc: 0.6446
# Epoch 2/10
# 88130/88130 [==============================] - 375s 4ms/step - loss: 1.1116 - acc: 0.6446
# Epoch 3/10
# 88130/88130 [==============================] - 372s 4ms/step - loss: 1.1120 - acc: 0.6428
# Epoch 4/10
# 88130/88130 [==============================] - 351s 4ms/step - loss: 1.1086 - acc: 0.6446
# Epoch 5/10
# 88130/88130 [==============================] - 359s 4ms/step - loss: 1.1075 - acc: 0.6458
# Epoch 6/10
# 88130/88130 [==============================] - 381s 4ms/step - loss: 1.1073 - acc: 0.6456
# Epoch 7/10
# 88130/88130 [==============================] - 396s 4ms/step - loss: 1.1042 - acc: 0.6457
# Epoch 8/10
# 88130/88130 [==============================] - 395s 4ms/step - loss: 1.0999 - acc: 0.6486
# Epoch 9/10
# 88130/88130 [==============================] - 406s 5ms/step - loss: 1.0997 - acc: 0.6483
# Epoch 10/10
# 88130/88130 [==============================] - 408s 5ms/step - loss: 1.1000 - acc: 0.6489
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# newed, an, mony nightomvoulith no mutn
# i bay surpaliely injuret none know jave,
# to hy pilours the whilijqis pection to.
# thought issunofed haply dutiage,
# i none iants upon in, and bspiad dwell,
# nor what he yeernign, aptilks stcinre,
# re's to love's cresting shamed my ktye.
# thy self issien straight thou allt of toour friend.
#  for i', by of lihe) hoad, i dute,
#   jusconcgured makes my head of my blood,
# keins lovees so cunnome, constancy tillodful,
# siilly alone of fabsings lust inken lief
# down blessad are shall, ever fier
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o love, and all in my knifel's first to thee,
# when i as write my self-love thee have obsery,
# whereto like him with sel wirion bearing.
# i find again, on all mine own decross,
# or all lessers, or the pour is thine own,
# i see despite the others that my sovered,
# of the motion on me then as a did me,
# without the base of nevertict, of brow,
# being many doth me all your sightleous discase,
# but thou forgod by a tender is your wary,
# much i form strong sin need, even thereins thou seep are depengance
# to make thee wherein my soundless too shower
# and of beauty and time's friend-beart, white and thee so shows,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o no in the state to the world to thee are deeds,
#   that i have she thine own sweet sightled,
# whilst i am the world i see the time,
# the rest presents thou art the world to thee,
# when i have seen the worsed with thee in thee,
#   this thou art thy self it self doth sour heart.
# me that i have still my deaths bear to me,
# hath thou thy self in his beauty still the beart,
# the world will not still the world to thee,
# i see the world i see the world to the still,
# the world with the better with the better's faces,
# that thou art all the true will bear to thee,
# when i am faults my desire doth spend'st the world the world doth shall stand
#
# Epoch 1/10
# 88130/88130 [==============================] - 405s 5ms/step - loss: 1.0954 - acc: 0.6494
# Epoch 2/10
# 88130/88130 [==============================] - 412s 5ms/step - loss: 1.0924 - acc: 0.6482
# Epoch 3/10
# 88130/88130 [==============================] - 404s 5ms/step - loss: 1.0909 - acc: 0.6499
# Epoch 4/10
# 88130/88130 [==============================] - 433s 5ms/step - loss: 1.0885 - acc: 0.6514
# Epoch 5/10
# 88130/88130 [==============================] - 425s 5ms/step - loss: 1.0834 - acc: 0.6513
# Epoch 6/10
# 88130/88130 [==============================] - 432s 5ms/step - loss: 1.0853 - acc: 0.6529
# Epoch 7/10
# 88130/88130 [==============================] - 427s 5ms/step - loss: 1.0864 - acc: 0.6512
# Epoch 8/10
# 88130/88130 [==============================] - 431s 5ms/step - loss: 1.0819 - acc: 0.6536
# Epoch 9/10
# 88130/88130 [==============================] - 450s 5ms/step - loss: 1.0815 - acc: 0.6532
# Epoch 10/10
# 88130/88130 [==============================] - 445s 5ms/step - loss: 1.0796 - acc: 0.6538
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# liling rhylybrre, thoughtms lays to knideous;
# and happtarint rillly every larger me,
#   thus threoke friendt on wag-itsiogh ony cajy:
# yetsarys, oniog in this,
# bett for my iswurimont :kinf's age.
# then worthnneve's elsenos argufe of trifg'hs
# not may of fl(ment them stone,
# think that give himstop and etiem like herparingh-:
# ind, to but noze heart mutjuse,
# which are ste) nothing life ok after;
# within me repie byowet ginared
# ie youth to youne , allwardson to mard,
# injure withowing, tall your richlest care.
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# whi should sees thee hoisting wish thee in truth,
# when i am was this, and that thou art art,
# to thy worth the looks, which is his praise sheet:
# i thoughts i almored to thee in thee,
# who receives of my boy, to the store,
# when i have conswers a account would?
# no tongured can more may see have it self're,
# with the looks no our farter which barge,
# stealisnow her buried compering, and thee wall
# when thou patiens to thy self it was.
#   and in which more hours thee i shall in pride,
# obut up their back bjoyl a miser pate:
# so thou public where show i decent, and for the bent,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou wilt be so divity that the better spirit,
# when thou shouldst in my self alone,
# disting since sight where thou art a man more.
# i my self with the world and straight in thee wallien.
# but thou subbrountly die of the world with thee,
# in the world and the world an end my love,
# may be be the beauty shall i see,
# how me no longer name no mand thee more,
# that i have shows not still the time show,
# in seems of the world with this best, then thou art,
# where thou art me then thou art the world so show,
#   that thou art my self alone, my self it might:
# and therefore are thee is my love shall thee,
#
# Epoch 1/10
# 88130/88130 [==============================] - 493s 6ms/step - loss: 1.0785 - acc: 0.6546
# Epoch 2/10
# 88130/88130 [==============================] - 496s 6ms/step - loss: 1.0758 - acc: 0.6547
# Epoch 3/10
# 88130/88130 [==============================] - 483s 5ms/step - loss: 1.0740 - acc: 0.6550
# Epoch 4/10
# 88130/88130 [==============================] - 474s 5ms/step - loss: 1.0709 - acc: 0.6566
# Epoch 5/10
# 88130/88130 [==============================] - 483s 5ms/step - loss: 1.0689 - acc: 0.6559
# Epoch 6/10
# 88130/88130 [==============================] - 474s 5ms/step - loss: 1.0682 - acc: 0.6578
# Epoch 7/10
# 88130/88130 [==============================] - 487s 6ms/step - loss: 1.0666 - acc: 0.6571
# Epoch 8/10
# 88130/88130 [==============================] - 496s 6ms/step - loss: 1.0657 - acc: 0.6565
# Epoch 9/10
# 88130/88130 [==============================] - 505s 6ms/step - loss: 1.0622 - acc: 0.6580
# Epoch 10/10
# 88130/88130 [==============================] - 503s 6ms/step - loss: 1.0602 - acc: 0.6593
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# may make my trw sworded chailed full stoe,
# but sad wertion etey: in truemenpers,
# procy) axtreingbrnowe concest,
#  yet what calls thant great tongues buriess:
#   ayes urges not by outward love,
#  al if aur for westing poor yotres virtuialoh)
# but swjjy's clack of you, whilst to menw
# 'will', and my heap susuers shuns adrem make,
# to this base op his ymows youth, wasthtexh alsing
# was thy 'will', of babe my beauties in thy cmihing hemiof.
# pop,
#  aminion courst vage,
# add, truen worse both through ecurcdad lamivk,
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# within the dear knowless the braving thee,
# lest buried that found that thy sweet brove,
# the mortaly, in part my glass sick with allion,
# to matter my breast my glass still, but which with thee:
#   that your sweet but thy part of thine,
# unhance might in blacke are men mine,
# every shall repayer still mine heart thee of may,
# and thinking and by thy soul doth slave kit,
#   this shall evermight doth parts to me,
#   your true love should translated chedies
# to make me set more brights of love reart,
# that in thee in your are beauty with my sight,
# and that my most, nor when thou for er
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# when thou dost bounty as the world by day,
#   that i have sworn that which i that bear
# men that i am my self with me,
#   so shall that the world with the world skill,
# to shall still the clouds of this shall thee more,
# the wardrit of their shall outlive thine,
# that thou art which more black and showers,
#   that i was with thou shouldst the sweet small deen,
# that thou art which your sweet self are sweets.
# and so your self are but thine as their rendings.
# then short me thine own dear rest a fear,
#   that she love all the sweet self at thee.
#   loich thou wilt thou thy self at the world.
#
# Epoch 1/10
# 88130/88130 [==============================] - 512s 6ms/step - loss: 1.0607 - acc: 0.6592
# Epoch 2/10
# 88130/88130 [==============================] - 508s 6ms/step - loss: 1.0604 - acc: 0.6606
# Epoch 3/10
# 88130/88130 [==============================] - 519s 6ms/step - loss: 1.0604 - acc: 0.6592
# Epoch 4/10
# 88130/88130 [==============================] - 525s 6ms/step - loss: 1.0610 - acc: 0.6582
# Epoch 5/10
# 88130/88130 [==============================] - 525s 6ms/step - loss: 1.0580 - acc: 0.6603
# Epoch 6/10
# 88130/88130 [==============================] - 539s 6ms/step - loss: 1.0570 - acc: 0.6617
# Epoch 7/10
# 88130/88130 [==============================] - 545s 6ms/step - loss: 1.0517 - acc: 0.6623
# Epoch 8/10
# 88130/88130 [==============================] - 551s 6ms/step - loss: 1.0525 - acc: 0.6621
# Epoch 9/10
# 88130/88130 [==============================] - 553s 6ms/step - loss: 1.0495 - acc: 0.6617
# Epoch 10/10
# 88130/88130 [==============================] - 561s 6ms/step - loss: 1.0497 - acc: 0.6625
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o feature's gause's hesposed dray his digad: east thereotion.
#   from limithn to my love?, wherein hove to thy gursers' heart?
# how i have cceached lia:
# dositiy, sum u the kyesming) willn nature;
# and belurs one your sweerpuyes gentle youth?
# or but as force, nor high bopt once keeped?
# but i his surle that bestaricling cater.
# unlooy ;reck her,ripver nwingted, eye freshes,
# to unnot folls durked woe hide's worr
# how limy die not point my fhele la-sept:
# and by mo, mine ial will holdness pent:
# there's at weed haves which bark iivents,
# at the cold won,
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# miste and thou mayst i self with use to show dean away.
#   that beauty good to him, and take love one.
#   till save all my moannat be a doth thee.
# and were it on the first thou dead note,
# although thou the sun of his sword, and such rail,
# making his youthful doth lively rekint:
#   yet by from the beauty, and their slost,
# the constancy, to like a wail upon me,
#   then were brainet will no it that die die,
# speaking on some spligured and this shade,
# although to be every wherein shore eyes,
#   if thou is my love conuter by from the grace is.
# i will at eyes of thee, my help of beauty,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# though i spour that my self alone, and there.
# o whose seasons and to thee thee i sweet.
# rice i thinks my thoughts of me in thee heart:
# and therefore is my love all thee all thee,
# when i am my love all thee i have subsed,
#   then be thou still will therefore to thee,
# when i have seem with self-subseectain,
# that i am not to be gones with thee hath thee bear,
# but thou thy self all the world to thee doth show,
#   then thou art the world beauty's compose.
# the worly so but then of the world so be,
#   to cold of the world will delivered.
#   then my foul thou art the world, and thine eyes,
#
# Epoch 1/10
# 88130/88130 [==============================] - 553s 6ms/step - loss: 1.0484 - acc: 0.6641
# Epoch 2/10
# 88130/88130 [==============================] - 562s 6ms/step - loss: 1.0454 - acc: 0.6633
# Epoch 3/10
# 88130/88130 [==============================] - 573s 7ms/step - loss: 1.0472 - acc: 0.6635
# Epoch 4/10
# 88130/88130 [==============================] - 567s 6ms/step - loss: 1.0424 - acc: 0.6652
# Epoch 5/10
# 88130/88130 [==============================] - 571s 6ms/step - loss: 1.0429 - acc: 0.6654
# Epoch 6/10
# 88130/88130 [==============================] - 580s 7ms/step - loss: 1.0423 - acc: 0.6661
# Epoch 7/10
# 88130/88130 [==============================] - 575s 7ms/step - loss: 1.0390 - acc: 0.6681
# Epoch 8/10
# 88130/88130 [==============================] - 587s 7ms/step - loss: 1.0382 - acc: 0.6664
# Epoch 9/10
# 88130/88130 [==============================] - 593s 7ms/step - loss: 1.0346 - acc: 0.6666
# Epoch 10/10
# 88130/88130 [==============================] - 596s 7ms/step - loss: 1.0387 - acc: 0.6650
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# how hear's deeingeoused, by of weld decay:
#   let vaiving medy sidesloflessly yout,
# the (death invoseld effree, ave remorns?
# thy heart un-grept threw bogten drown yiu.
#   selfipagressed the riperal reyor airance,
# as still content's   in lotignebsous jett,
#   this coldant sick with by care of etem:
# now worthd-feel, thy knowledge unfair grief,
#   but evil form oth worchface and slowf tuckson minu
# with my extentusbrecused with sownly,
# and to those tay may dold which nuol my are,
# kill i have sfory rothe doth she wellm)
# beina lemper your wooe i nence, do abpide
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# how must needs to go despite asing ffore,
# and true, which i see, these livious mine,
#   where true thy self which suppose to thee,
# for some in thy bolden than happirh my sight,
# and put thy self mine hotion of thy sake,
# as thou be fach my new-sounds in selllies,
# from my love's fair black him soul the line,
# but for pity made mad mane, till to slavere.
#   give heaven i am remoan to bastare
# to were to that pray a deceased farth?
# if it with the own bury prime,
#   mine eyes well, to far for great my self forth,
#   all to thy soul be to witness of thy prove
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou art my self alone, a dear parts:
# for thou art my heart that thou art beau
# suffered with the world so beauty be grow.
# thou should by thy self the world to make,
# that should my heart to the painted sit,
# for should made a time doth puting to thee,
# when in thee is my love as fair assuled,
#   then be a fire in my self a bath a seemity?
# i see a man my self in thy self thou shouldst sun,
# and beauty be through in this same decreesed.
#   his beauty should fortune so blessed to me.
#   this took and praises be through the shore,
# and therefore it may shall live in thy shall dear heart
#
# Epoch 1/10
# 88130/88130 [==============================] - 605s 7ms/step - loss: 1.0347 - acc: 0.6661
# Epoch 2/10
# 88130/88130 [==============================] - 596s 7ms/step - loss: 1.0360 - acc: 0.6685
# Epoch 3/10
# 88130/88130 [==============================] - 615s 7ms/step - loss: 1.0345 - acc: 0.6676
# Epoch 4/10
# 88130/88130 [==============================] - 608s 7ms/step - loss: 1.0334 - acc: 0.6672
# Epoch 5/10
# 88130/88130 [==============================] - 613s 7ms/step - loss: 1.0311 - acc: 0.6683
# Epoch 6/10
# 88130/88130 [==============================] - 617s 7ms/step - loss: 1.0320 - acc: 0.6670
# Epoch 7/10
# 88130/88130 [==============================] - 629s 7ms/step - loss: 1.0317 - acc: 0.6674
# Epoch 8/10
# 88130/88130 [==============================] - 635s 7ms/step - loss: 1.0306 - acc: 0.6685
# Epoch 9/10
# 88130/88130 [==============================] - 642s 7ms/step - loss: 1.0269 - acc: 0.6701
# Epoch 10/10
# 88130/88130 [==============================] - 688s 8ms/step - loss: 1.0242 - acc: 0.6702
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# then wift true that your 'will ong you in o'eb
# resents ene in samblled of one, harp alone.
# or con, thou wilt be wits as man thked veraver,
# from throun yourngrest to dmy day it skpe.
# then temons your stite it vackle bibst,
# to do rogo'tlers of toiled, therefoun.
#   wou tils took henty gries vend evi have not be gree.
# with fallnful glest preseefumfalls seemneds,
# live turns uncesiem) the ornam, to make dook?
# thus if his mild, raquiesany ma.n you to teen's,
#   do i love's might,
#  giving from more engifufllack, it clief
# and his grasemsagh to truty in one, papt:
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# then thou corshers of strong inflate to row on his siled:
# but thou somethen it is but one, rown.
# for thou should by souls to see have her,
# which i not to spend, for try true seeing,
# of my heart her, feathered shall in the to'ry
# the ornament of atten thee aot my false
# on thee, and still thy least of thine on,
# that i was not strong hungary disart,
# and therefore to be fortionred of my thine eir,
# that blessinks to guest of vouch the spore,
# more hand the line, mine eyes have i throwe,
# the rank you are their scastips to the mind,
# should beauthor digniviewers are spent?
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou should love's fingour of my more sour,
# and the self-substance i bring form of love,
# and therefore to be fortune the world so died,
# my self thy sweet self thou prevered some,
# i must love that to be self to sing heart:
# and that thou the stern to rushed for my sight,
# when i from the self-say my self doth live,
# and the present i'll delights to the spend's wind,
# or at the strength of the strength of thine.
# then with the sad of thine eyes have doth trace.
# so all my love's spite to me then the truth,
# that to the eye to doth the mort, and thee my sight,
# when the world to the summer on the frow of thee.
#
# Epoch 1/10
# 88130/88130 [==============================] - 675s 8ms/step - loss: 1.0267 - acc: 0.6696
# Epoch 2/10
# 88130/88130 [==============================] - 718s 8ms/step - loss: 1.0282 - acc: 0.6688
# Epoch 3/10
#  7424/88130 [=>............................] - ETA: 11:59 - loss: 0.9553 - acc: 0.6909
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2194fa9d2ccf> in <module>
#       2 warnings.filterwarnings('ignore')
#       3 for iteration in range(50):
# ----> 4     model.fit(X, y, batch_size=128, nb_epoch=10)
#       5
#       6     for temperature in [1.5, 0.75, 0.25]:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
