# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file

from functools import partial
from bayes_opt import BayesianOptimization

import numpy as np
import random
import sys
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading dataset

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read().lower().split('\n')
poem_list = []
raw_text = ''
for j in range(len(text) + 1):
    if j == len(text):
        poem_list.append(raw_text)
    elif text[j] == '':
        if raw_text != '':
            poem_list.append(raw_text)
        raw_text = ''
        continue
    elif text[j][-1].isdigit():
        continue
    else:
        subsentence = text[j] + '\n'
        raw_text += subsentence  
print('Number of poems:', len(poem_list))
# Out:
# Number of poems: 154

# %% [markdown]
# ## Create Sequences

# %%
# organize into sequences of characters
def create_sequence(raw_text, length, step):
    sequences = []
    next_chars = []
    for i in range(0, len(raw_text) - length, step):
        # select sequence of tokens
        seq = raw_text[i:i + length]
        # store
        sequences.append(seq)
        next_chars.append(raw_text[i + length])
    return sequences, next_chars

# %%
length = 40
step = 1
sequences = []
next_chars = []
for poem in poem_list:
    sub_sequences, sub_next_chars = create_sequence(poem, length, step)
    sequences += sub_sequences
    next_chars += sub_next_chars
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 88130

# %% [markdown]
# ## Character Mappings and Inverse Mappings

# %%
poem_string = "".join(poem_list)
chars = sorted(list(set(poem_string)))
char_index_map = dict((c, i) for i, c in enumerate(chars))
index_char_map = dict((i, c) for i, c in enumerate(chars))
vocab_size = len(char_index_map)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 38

# %% [markdown]
# ## Vectorization

# %%
X = np.zeros((len(sequences), length, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sequences):
    for t, char in enumerate(sentence):
        X[i, t, char_index_map[char]] = 1
    y[i, char_index_map[next_chars[i]]] = 1

# %% [markdown]
# ## Build the RNN Training Model

# %%
import warnings
warnings.filterwarnings('ignore')
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(length, len(chars))))
model.add(Dense(len(chars))) 
model.add(Activation('softmax'))

model.summary()   

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# Build model...
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               85504
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                4902
# _________________________________________________________________
# activation_1 (Activation)    (None, 38)                0
# =================================================================
# Total params: 90,406
# Trainable params: 90,406
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## Sampling function (combining softmax with temperature)

# %%
def sample(preds, temperature):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Training the model with outputs

# %%
import warnings
warnings.filterwarnings('ignore')
for iteration in range(10):
    model.fit(X, y, batch_size=128, nb_epoch=10)

    for temperature in [1.5, 0.75, 0.25]:
        print()
        print('----- temperature parameter:', temperature)

        generated = ''
        sentence = "shall i compare thee to a summer's day?\n"
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        line_count = 0
        while (line_count <= 12):
            x = np.zeros((1, length, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_index_map[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = index_char_map[next_index]
            
            if next_char == '\n':
                line_count += 1

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\Steve\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 88130/88130 [==============================] - 40s 458us/step - loss: 2.0581 - acc: 0.3933
# Epoch 2/10
# 88130/88130 [==============================] - 48s 547us/step - loss: 1.6759 - acc: 0.4911
# Epoch 3/10
# 88130/88130 [==============================] - 53s 601us/step - loss: 1.5628 - acc: 0.5204
# Epoch 4/10
# 88130/88130 [==============================] - 68s 771us/step - loss: 1.4929 - acc: 0.53876s - loss: 1.4921 - acc: 0.5 - ETA: 2s - lo
# Epoch 5/10
# 88130/88130 [==============================] - 46s 522us/step - loss: 1.4437 - acc: 0.5504
# Epoch 6/10
# 88130/88130 [==============================] - 47s 532us/step - loss: 1.4062 - acc: 0.5609
# Epoch 7/10
# 88130/88130 [==============================] - 51s 574us/step - loss: 1.3773 - acc: 0.5685
# Epoch 8/10
# 88130/88130 [==============================] - 53s 606us/step - loss: 1.3528 - acc: 0.5741
# Epoch 9/10
# 88130/88130 [==============================] - 60s 676us/step - loss: 1.3342 - acc: 0.5804
# Epoch 10/10
# 88130/88130 [==============================] - 62s 699us/step - loss: 1.3188 - acc: 0.58382s - l
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# for reforgn wited slymerl of you remay,
# ar eaf hell beauty's chyer recorsiou,
# and wherefis, iamarded divayed ,
# dow's iehaill, ks inveragnatit his oftant nugely my
#   they viam expender them do bver's storn
# have they glasing flies meeastore lourlest
# or love ward 'a'gms, lovi seemint epent.
#   chald these outknce your frommom tulls b.
# thds, flower perriking hanth
# incom you outblessricted erf most onbran?
# ro forning me forins (ilate one eress rackd,
# and she is rrcedy upons, loin wat?
# leating theired's ewgreit try cupant and.
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# why should me not calls rueble for where.
#   and their verse show from thine ocrean gry,
# and maigh thy namb be should his never bot,
#   thou far thy minding change the pay,
# their hand my change of suncely doth line,
#   for my love, thou in thy driss againted stealtith
# but solekly take a the purpose pleasurered,
#   therefore in my days and intired his him,
# and there i that for mine own mind'r poor deeds,
# thy commoned and you are, and make did most thee,
# for since my love thences to other and flow,
#   that beauty's sitce indence the lease in me,
# if thou lov'st have view seas my all teals
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# when i should their change their self thee decease,
# and in my body not the thee their words,
#   the thee the the the thence that their dearly,
# and their compouch the the still the treasure,
# and thence of thy self thy heart the world with thee,
#   the other than the the thee with thee thee,
# when i not the thear and the the thee,
# the thee they would the though and their growing,
# and their back of thy heart that i the treasure,
#   then accunce their beauty the thee thee,
#   their self deserves the the world with thee,
#   then thou art the the the the with my love.
# then dost the the to thee in their best,
#
# Epoch 1/10
# 88130/88130 [==============================] - 67s 755us/step - loss: 1.3001 - acc: 0.58748s - loss: 1.2959 - acc: 0.58 - ETA:  - ETA: 1s - loss: 1.3004 - a - ETA: 0s - loss: 1.3005 - acc
# Epoch 2/10
# 88130/88130 [==============================] - 76s 862us/step - loss: 1.2881 - acc: 0.5923
# Epoch 3/10
# 88130/88130 [==============================] - 81s 922us/step - loss: 1.2797 - acc: 0.5944
# Epoch 4/10
# 88130/88130 [==============================] - 100s 1ms/step - loss: 1.2697 - acc: 0.5974
# Epoch 5/10
# 88130/88130 [==============================] - 164s 2ms/step - loss: 1.2574 - acc: 0.6006
# Epoch 6/10
# 88130/88130 [==============================] - 99s 1ms/step - loss: 1.2496 - acc: 0.6033
# Epoch 7/10
# 88130/88130 [==============================] - 122s 1ms/step - loss: 1.2408 - acc: 0.6074
# Epoch 8/10
# 88130/88130 [==============================] - 163s 2ms/step - loss: 1.2321 - acc: 0.6080
# Epoch 9/10
# 88130/88130 [==============================] - 158s 2ms/step - loss: 1.2256 - acc: 0.6083
# Epoch 10/10
# 88130/88130 [==============================] - 184s 2ms/step - loss: 1.2211 - acc: 0.6106
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# whech have broa, others shalire decreeuiched,
# and dull ry ohc-mily hath withined oof.
# theat efuyber praut: hereowinait, it ma's heis.
#   : ack in not down love friend f sher houche from
# yetrojuten knciking skip by it perceess:
# agar thee ar rail cleefully beloved thase,
# criaksed belivse fun, 'wis my love buracliguestion,
#   for 'cain in my namage wheching mhent miredoos,
# sall over) seem voecered which apperage rinet
# unless to thine endigs my codtaace once,
# or guace-procefol so ream upon no yoat,
# torned suir not to showes crulft and look,
#   i wiubetied brivery by new nimkhing me.
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# that is thy self or you aid in me with care,
# to thy self in the aterfect of with my deeds,
# the but in my life not encever-in rain,
# when i a somethied broud excuse shall deed,
# than the fingers and discall by despised,
# and single muse out cancioned fair in mine,
# so for their complexion with change not that eye,
# that yet hast she what praise a give put,
# unless are the sengres still to be rained every womeh,
# they with thou art'st too me assured thine,
# so there as doth fair she son, which in one dead,
# and his gav'st he will my grown fair are
# from their wand'ring sweet sin crart,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou dost be the stars that this thy self thy sight,
# and the world with thy self thy self thy souldst the store,
# and that the sun's dead with thy self thy soul,
# the mortal thee in the rights of such mays,
# and in the world and the stars that this shown thee,
# the sunk in the world and seem that thou dost her bread,
#   and then but the sengened and the beauty,
# and then thy self thy self thy self thy self thy soul'st in me,
#   that in the world make the sunked may not
# to see the strength and the world that the foes but so see
# the world and seem mine own abourd of thee,
#   then i have i thinking thy worst one teet:
# and to the sunken on the praises would be to thee,
#
# Epoch 1/10
# 88130/88130 [==============================] - 190s 2ms/step - loss: 1.2126 - acc: 0.6130
# Epoch 2/10
# 88130/88130 [==============================] - 193s 2ms/step - loss: 1.2051 - acc: 0.6165
# Epoch 3/10
# 88130/88130 [==============================] - 197s 2ms/step - loss: 1.2000 - acc: 0.6173
# Epoch 4/10
# 88130/88130 [==============================] - 199s 2ms/step - loss: 1.1936 - acc: 0.6190
# Epoch 5/10
# 88130/88130 [==============================] - 198s 2ms/step - loss: 1.1891 - acc: 0.6197
# Epoch 6/10
# 88130/88130 [==============================] - 206s 2ms/step - loss: 1.1842 - acc: 0.6216
# Epoch 7/10
# 88130/88130 [==============================] - 206s 2ms/step - loss: 1.1804 - acc: 0.6245
# Epoch 8/10
# 88130/88130 [==============================] - 215s 2ms/step - loss: 1.1728 - acc: 0.6249
# Epoch 9/10
# 88130/88130 [==============================] - 216s 2ms/step - loss: 1.1675 - acc: 0.6255
# Epoch 10/10
# 88130/88130 [==============================] - 222s 3ms/step - loss: 1.1633 - acc: 0.6289
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# when ills it i slofiset in me,
# aflate with tlave yeful e ?' eich found tilave get out songpen, onty,
# fin.
# the feaunt for style hear as forresf it thinking,
#   but thoinuquen forbunt ost ornam's ifligored,
# 'howefor name nor outward note love's ill.
# to the tormumed with whosed orveal wad-looks,
#   'tis
# wlecitough it, i may brief their maswein,
# to haip musching of thy libed would now crooned,
# for made old wealth to play these east room which voul wanter's,
# and prrmiving steel bitterness is boin,
# suchfound yound bhiourusarfust, attime,
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# why are use single as thus though in poet,
# which for thou throught to dies meshow def
# by and thy self? the world, which had strongs doth still,
# ten to give, when i sid all wronger crowned,
# whine of mawjed,
#   since huge state's braving sweet fierd thee,
#   to every back name for coett in knows,
# that the triath, and do this proud impend,
# then now a thing's trees do not better with my love.
#   and yet best i to worth all along,
# as back and all a bath the lily light true,
# or beans i have his sward from my foul do none this some fair,
# where was bear from the lily in their days.
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# why dost thou art the strength of the state,
# and therefore all my heart which i say and woe,
#   that then thou dost be the world with heavenly most,
# and then then the strength which i say and doth still,
# to speed to the strength in the fire thee,
#   then i will see the stars the world may,
# the world hath the strength of thee,
# and then be diseas shall i think mayst be,
#   and then thou art the strength of the world mayst bear,
# that which i say adully the store,
# and then the treasure of the world with heavenly dwell,
# to the sweet face shadow in the store,
# that mine eyes would death the treasure there is brow,
#
# Epoch 1/10
# 88130/88130 [==============================] - 225s 3ms/step - loss: 1.1586 - acc: 0.6289
# Epoch 2/10
# 88130/88130 [==============================] - 227s 3ms/step - loss: 1.1565 - acc: 0.6293
# Epoch 3/10
# 88130/88130 [==============================] - 231s 3ms/step - loss: 1.1534 - acc: 0.6316
# Epoch 4/10
# 88130/88130 [==============================] - 241s 3ms/step - loss: 1.1499 - acc: 0.6322
# Epoch 5/10
# 88130/88130 [==============================] - 240s 3ms/step - loss: 1.1465 - acc: 0.6321
# Epoch 6/10
# 88130/88130 [==============================] - 248s 3ms/step - loss: 1.1426 - acc: 0.6336
# Epoch 7/10
# 88130/88130 [==============================] - 260s 3ms/step - loss: 1.1429 - acc: 0.6339
# Epoch 8/10
# 88130/88130 [==============================] - 268s 3ms/step - loss: 1.1364 - acc: 0.6363
# Epoch 9/10
# 88130/88130 [==============================] - 266s 3ms/step - loss: 1.1323 - acc: 0.6362
# Epoch 10/10
# 88130/88130 [==============================] - 274s 3ms/step - loss: 1.1315 - acc: 0.6375
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# o laystitued in partuackless in truptirat:
# o swende, cinse at wises fentthfocts to saar
# firmest being fair feeing each sunfaping,
# a vowezeds stans -plimsan tifaket what worth held?
# o 'griat false compasing, naiging stee?
# wx that fired bearth, to a aelines of,
# thee keeps me oftyling toucked arrnon:w
# wors a'send in evency mey, tracked mocre-,
# foirancy survids buriget toftited lose,
# that i do drageurd by this his mindless lian,
# gut ond kings of thy worvaved our as,
# hems do i not as hellit harg.lour,
#  be 'gainst wide clouds frown, norgh ageblidy
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou should nothing is others' resportion,
# a woos this disarned, where you whether doth lie,
# men in my grieful excuse and that which mine,
# that i being many was compared foolished,
# the liar lart with tumbs to may shorlety:
# roses hand tongues the tieding his hide,
# within thy sweet see lips in that is thee.
# after shadow thrice in a delight, where told sing,
# against the true life in thee to thee heaven,
# of what me your thoughts on heaven in thee,
# which divent for what mine eyes, and waste,
# which works as lamenished speak of my jewel,
# thou shalt filed i an all-e to thee,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# when i will be forgetful the time that thou in thee,
#   that is this this thine eyes of thee to thee,
#   then if this thoughts in their pleasure,
# that in the world with the windows that thee,
#   to thee i am another then thou art,
# as those that thou the star tongues in thee,
#   then if the treasure of thee i am to show,
# to show, when thou art the stillise of smore shows,
#   this shall selful to the stards of where,
# that the world with the windows shall see,
# but then mortal to thee in their pleasure,
# and then thou art the stars to thee to thee,
#   this thou shall thy sweet self dost thou see,
#
# Epoch 1/10
# 88130/88130 [==============================] - 284s 3ms/step - loss: 1.1286 - acc: 0.6373
# Epoch 2/10
# 88130/88130 [==============================] - 296s 3ms/step - loss: 1.1251 - acc: 0.6407
# Epoch 3/10
# 88130/88130 [==============================] - 290s 3ms/step - loss: 1.1180 - acc: 0.6413
# Epoch 4/10
# 88130/88130 [==============================] - 283s 3ms/step - loss: 1.1143 - acc: 0.6422
# Epoch 5/10
# 88130/88130 [==============================] - 302s 3ms/step - loss: 1.1171 - acc: 0.6412
# Epoch 6/10
# 88130/88130 [==============================] - 308s 3ms/step - loss: 1.1113 - acc: 0.6443
# Epoch 7/10
# 88130/88130 [==============================] - 315s 4ms/step - loss: 1.1098 - acc: 0.6448
# Epoch 8/10
# 88130/88130 [==============================] - 316s 4ms/step - loss: 1.1063 - acc: 0.6436
# Epoch 9/10
# 88130/88130 [==============================] - 312s 4ms/step - loss: 1.1026 - acc: 0.6456
# Epoch 10/10
# 88130/88130 [==============================] - 315s 4ms/step - loss: 1.1028 - acc: 0.6449
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# anothicer rumbel in oot a maet.
# while nore thatres, add hlaid itterred,
# feath afound against thy pict'rity marge:
# , by i suggest be mortal fine piuch re's heabsed,
# call) gift embaus disten so long all,
# when love's delive fulls my verse kilffect,
# nan,ed speal, and glavos abunate up lust
# a malkey love) incharaled
# whilite's chia(meat, beaut from my self grith:
# doit's loof) !'very poor wror, assured,
# o for all plag'sterble hher' dornief:
# alo why most ey prows, by toot,fle knife:
#  . wret himarved old of theight things deeds?
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# fo thy beauty's some to self-dost more discopse,
# the princes each are fresh which i dree,
# and hope and thinks of me for my mind do be,
#   tortance have not love, to have, their blood,
# are presends his longer mure's sweet breathed with ass:
# then of these wants and thought see time,
#   let thou large repointers the love
#   are have cold vowen are works will being drimks,
#   and thou lov'st has when your combloce,
# at my drownal still me clearer part,
# the doth make me shall the turn whtlly triumb
# against then thou that beauty gives tearled,
#   the mire pritied aflot faults are meth,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# whence with thy praise the summer beauty?
# or many a thinds of the true absence stee,
#   and therefore many a thand's former deared
# whilst thou shouldst the world of things breath.
# but thou art of me thou art sumbent with his spirit,
# but thou shouldst with thee for the true spend
# should that thou art so shall to the cheek,
# and that your sweet self art summer's love.
#   then i love thee for my self and chopt dwell besee,
# the book of things with the world of thee,
# and thou art so shall by the true your seed,
# and thou art the counterpart that i have strength to me,
#   that the world with the time but be the complen,
#
# Epoch 1/10
# 88130/88130 [==============================] - 322s 4ms/step - loss: 1.0985 - acc: 0.6451
# Epoch 2/10
# 88130/88130 [==============================] - 334s 4ms/step - loss: 1.0960 - acc: 0.6467
# Epoch 3/10
# 88130/88130 [==============================] - 336s 4ms/step - loss: 1.0951 - acc: 0.6471
# Epoch 4/10
# 88130/88130 [==============================] - 345s 4ms/step - loss: 1.0918 - acc: 0.6487
# Epoch 5/10
# 88130/88130 [==============================] - 345s 4ms/step - loss: 1.0902 - acc: 0.6498
# Epoch 6/10
# 88130/88130 [==============================] - 347s 4ms/step - loss: 1.0873 - acc: 0.6494
# Epoch 7/10
# 88130/88130 [==============================] - 364s 4ms/step - loss: 1.0851 - acc: 0.6511
# Epoch 8/10
# 88130/88130 [==============================] - 360s 4ms/step - loss: 1.0850 - acc: 0.6509
# Epoch 9/10
# 88130/88130 [==============================] - 349s 4ms/step - loss: 1.0831 - acc: 0.6508
# Epoch 10/10
# 88130/88130 [==============================] - 293s 3ms/step - loss: 1.0819 - acc: 0.6519
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# whence meight day, po, him compy heav neutht,
# did do invention is, him i and part.
#   drwinking the sel filong his gains, steew: bhert'red,
# is pasint to tell wrived wer it, can oce,
#   this feigned all offear is fulken,
# cos of a mad all, for me for devired'st,
# when moin, and couls memory opetth, burned viguts,
# onpopy's not rub;rac'st his make now s sport,
# take the ocean for woed that love he, bub
# mortues, have, you pen she wrons assured
# to love, replente influeness barr,
# ond, had too be,i
# thire, cenlure, thring'r a hear liveness  watt
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# why sheal was we proudled she do i mattered
# but within the leasure of whets with thee,
# when that bears them mortoust beauty right
# so thy bamous to day thee of mine to esteed,
# and frunts to the great of death's injury.
# may death delire we so freebles she that me,
# for thou so forther's this this is thee blind,
#   as sul memory the were but and this his thief.
# thy self thy sweet forfic with these bear me,
# for i see doth his veils, and your render,
#   and then shoot my love's compees, that flqueled,
# and that still shall too be these bloom-with thee virse,
# will that to thee all ourplearve themselves forected,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thee is but as the leasure of me, then bear bring
# when thou art our in the cheeks thee thee,
#   the sound in the world and there beauten need.
# i thought i am all the leasure of thee,
#   therefore then mortal to the world than thee,
#   the love's some their present which straight in thee,
#   the wors a time that this thou mayst come,
# which is not so the love and there beared
# by the world which i should i will should double
# crill of my love thee of my self thy show,
# the strength and there beatent is thee, from thee,
# and therefore their praise the time that steel,
# the sun is the thing the world and there wand'ring strangely be,
#
# Epoch 1/10
# 88130/88130 [==============================] - 299s 3ms/step - loss: 1.0777 - acc: 0.6523
# Epoch 2/10
# 88130/88130 [==============================] - 358s 4ms/step - loss: 1.0777 - acc: 0.6506
# Epoch 3/10
# 88130/88130 [==============================] - 384s 4ms/step - loss: 1.0768 - acc: 0.6530
# Epoch 4/10
# 88130/88130 [==============================] - 374s 4ms/step - loss: 1.0743 - acc: 0.6530
# Epoch 5/10
# 88130/88130 [==============================] - 368s 4ms/step - loss: 1.0718 - acc: 0.6539
# Epoch 6/10
# 88130/88130 [==============================] - 364s 4ms/step - loss: 1.0706 - acc: 0.6548
# Epoch 7/10
# 88130/88130 [==============================] - 388s 4ms/step - loss: 1.0697 - acc: 0.6557
# Epoch 8/10
# 88130/88130 [==============================] - 407s 5ms/step - loss: 1.0679 - acc: 0.6550
# Epoch 9/10
# 88130/88130 [==============================] - 409s 5ms/step - loss: 1.0674 - acc: 0.6545
# Epoch 10/10
# 88130/88130 [==============================] - 419s 5ms/step - loss: 1.0646 - acc: 0.6570
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# loveiness , althout, : even out angel ?
# yed, which flesi? rechen not skill of it
# writit, alo,   doth invent i weig:fence,
# yet thing nature's time wer eyes  'row nefcks'samaine.
# nothing timply downty fairering, and prime,
# line he face stisequey his doth heat prevent kname,
# who leaves is mine eye bur wis a liligreld
# jullds of erecrastion with looksedy on thing hour most,
# 'ntrowhoul every ward, wretcher desired,
#   alacked would, and 'wy belomustions lost:
# through plagc abse, thou straight willing annod,
# nougwitled tender truth of my desire
# tose codlues my breast, made proud tovctk,
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou art not yet not with thy sweet self the deeisgilled,
# and he going, than it thy love's tender me.
#   deathost do show hence thee to swear invitain,
# for if he earth of their proud of thine,
# and ever so decase beauty's fear of itned,
# whilst in the all, and he that giud fait
# of mine eye is truth,
# and i made of slall tome, and most hold,
#   a beared shall i love as thou live,
# as contracted my love's love's proceion,
# hast looks hath my love's beauty be forthed still,
# that in the least preciots are in wary,
# but is so mery still be minds and heart,
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou art as thou art but the worth and there bregent,
# that thou art the world and the worth are seen,
# without thou art our see anget me shaken
# to works and thought thou art onemer thee,
#   though i see thee of this impetured the proud,
# and the show me with the strength and shall still,
# that i have thee i am another stand,
# and the world will be the worth to thee,
#   then more thou art not shall too show it:
# the roses the world will in the bases and prove,
#   then my heart i am another still will be.
# if i am shames and there is but the worth
# that in the world of the strength and thee,
#
# Epoch 1/10
# 88130/88130 [==============================] - 431s 5ms/step - loss: 1.0618 - acc: 0.6564
# Epoch 2/10
# 88130/88130 [==============================] - 430s 5ms/step - loss: 1.0620 - acc: 0.6577
# Epoch 3/10
# 88130/88130 [==============================] - 428s 5ms/step - loss: 1.0581 - acc: 0.6592
# Epoch 4/10
# 88130/88130 [==============================] - 426s 5ms/step - loss: 1.0587 - acc: 0.6582
# Epoch 5/10
# 88130/88130 [==============================] - 442s 5ms/step - loss: 1.0565 - acc: 0.6588
# Epoch 6/10
# 88130/88130 [==============================] - 430s 5ms/step - loss: 1.0548 - acc: 0.6598
# Epoch 7/10
# 88130/88130 [==============================] - 427s 5ms/step - loss: 1.0543 - acc: 0.6581
# Epoch 8/10
# 88130/88130 [==============================] - 436s 5ms/step - loss: 1.0513 - acc: 0.6610
# Epoch 9/10
# 88130/88130 [==============================] - 439s 5ms/step - loss: 1.0473 - acc: 0.6619
# Epoch 10/10
# 88130/88130 [==============================] - 437s 5ms/step - loss: 1.0506 - acc: 0.6603
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou like fibled ip be fre?my from thee.
# sla
# if is byly datels of dring waste,
#  him no , so -perpe stonds toldour your jo(wery.
# each in sture, who they would come of quite thy wan.forth,
# the grocion si, wer, youth confided time:
#   ilacquiouser hig beauty do in that when no,
# alnfontless groan's shad-sufren from theeest
# of love a  nour wery lies of eye do you,
# someings oj, beating to do i at best,
# wood is on beauty's cheemounting hand:
# al usong millames of a cheer,
#   unlooked wailed another the stares this fices,
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou art the world for the world, and fors
# in his thing all thy show'st and stay,
# altive of fear ill doth shore, as the worls for living old end,
# and in see, men with a perfects doth say,
# to how with bard and his found and her pass,
# is love is thy beins mayst life in outw,
# by cannot by some of the thoughts out to this soure,
# and my most decays the some rant, when sing,
# and barren and waring they in love beguiled,
# the wisowed shall not have whe they see yet,
# happy the wantang thy selt an wofowed black,
# but if thou despair and in you in pricked weep,
# the worst and heaven the sound hunding targe.
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# thou art the self-love may with my self to thee,
# and thou art the sun before the sun fart,
# to show my self thy self thou art the sun dear,
#   the  and therefore to the summer in my sight,
# and by and therefore the world with side,
# then in the world of self, and he well, till my sight,
# and to the summer's treasure in the worl,
# how haven them then my self a seet best me,
#   and they seest the treasure of thy self and hearts
# that thou art the sun far a man ill my sight,
# my self a seet being fashines of thy self still,
#   then if thou shouldst not so suffer in,
# feashs of thine of my self thou be shows are seen,
#
# Epoch 1/10
# 60672/88130 [===================>..........] - ETA: 2:22 - loss: 1.0289 - acc: 0.6684
