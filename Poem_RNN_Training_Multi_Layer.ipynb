# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file

from functools import partial
from bayes_opt import BayesianOptimization

import numpy as np
import random
import sys
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading dataset

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read().lower().split('\n')
poem_list = []
raw_text = ''
for j in range(len(text) + 1):
    if j == len(text):
        poem_list.append(raw_text)
    elif text[j] == '':
        if raw_text != '':
            poem_list.append(raw_text)
        raw_text = ''
        continue
    elif text[j][-1].isdigit():
        continue
    else:
        subsentence = text[j] + '\n'
        raw_text += subsentence  
print('Number of poems:', len(poem_list))
# Out:
# Number of poems: 154

# %% [markdown]
# ## Create Sequences

# %%
# organize into sequences of characters
def create_sequence(raw_text, length, step):
    sequences = []
    next_chars = []
    for i in range(0, len(raw_text) - length, step):
        # select sequence of tokens
        seq = raw_text[i:i + length]
        # store
        sequences.append(seq)
        next_chars.append(raw_text[i + length])
    return sequences, next_chars

# %%
length = 40
step = 1
sequences = []
next_chars = []
for poem in poem_list:
    sub_sequences, sub_next_chars = create_sequence(poem, length, step)
    sequences += sub_sequences
    next_chars += sub_next_chars
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 88130

# %% [markdown]
# ## Character Mappings and Inverse Mappings

# %%
poem_string = "".join(poem_list)
chars = sorted(list(set(poem_string)))
char_index_map = dict((c, i) for i, c in enumerate(chars))
index_char_map = dict((i, c) for i, c in enumerate(chars))
vocab_size = len(char_index_map)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 38

# %% [markdown]
# ## Vectorization

# %%
X = np.zeros((len(sequences), length, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sequences):
    for t, char in enumerate(sentence):
        X[i, t, char_index_map[char]] = 1
    y[i, char_index_map[next_chars[i]]] = 1

# %% [markdown]
# ## Build the RNN Training Model

# %%
import warnings
warnings.filterwarnings('ignore')

print('Build model...')
model = Sequential()
model.add(LSTM(200, return_sequences=True, input_shape=(length, len(chars))))
model.add(LSTM(100))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.summary()   

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 40, 200)           191200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100)               120400
# _________________________________________________________________
# dense_2 (Dense)              (None, 38)                3838
# _________________________________________________________________
# activation_2 (Activation)    (None, 38)                0
# =================================================================
# Total params: 315,438
# Trainable params: 315,438
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Sampling function (combining softmax with temperature)

# %%
def sample(preds, temperature):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Training the model and generating outputs

# %%
import warnings
warnings.filterwarnings('ignore')

for iteration in range(3):
    model.fit(X, y, batch_size=128, epochs=10)

    for temperature in [1.5, 0.75, 0.25]:
        print()
        print('----- temperature parameter:', temperature)

        generated = ''
        sentence = "shall i compare thee to a summer's day?\n"
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        line_count = 0
        while (line_count <= 12):
            x = np.zeros((1, length, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_index_map[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = index_char_map[next_index]
            
            if next_char == '\n':
                line_count += 1

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Epoch 1/10
# 88130/88130 [==============================] - 95s 1ms/step - loss: 3.0158 - acc: 0.1679
# Epoch 2/10
# 88130/88130 [==============================] - 97s 1ms/step - loss: 3.0107 - acc: 0.1686
# Epoch 3/10
# 88130/88130 [==============================] - 115s 1ms/step - loss: 3.0108 - acc: 0.1681
# Epoch 4/10
# 88130/88130 [==============================] - 108s 1ms/step - loss: 3.0101 - acc: 0.1675
# Epoch 5/10
# 88130/88130 [==============================] - 118s 1ms/step - loss: 3.0111 - acc: 0.1679
# Epoch 6/10
# 88130/88130 [==============================] - 136s 2ms/step - loss: 3.0108 - acc: 0.1676
# Epoch 7/10
# 88130/88130 [==============================] - 155s 2ms/step - loss: 3.0101 - acc: 0.1669
# Epoch 8/10
# 88130/88130 [==============================] - 165s 2ms/step - loss: 3.0109 - acc: 0.1683
# Epoch 9/10
# 88130/88130 [==============================] - 176s 2ms/step - loss: 3.0105 - acc: 0.1674
# Epoch 10/10
# 88130/88130 [==============================] - 183s 2ms/step - loss: 3.0114 - acc: 0.1681
#
# ----- temperature parameter: 1.5
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# bkwm otw aieg
# nal aotoyd
# er v
# l l h bteshi hs eolikvecsoegxmt o,hh epvdt em erstt
#  co
# aib ure.e,
# ssr tdeolrs anwo,vheuwaletgebnh.s
# h aqrvsnalnpgiyd lmsoft n psraso thchhqe a
# eolfisdrrarh fpgcalr oe s s utidr,mlo aasna,p d emnnoe aw irshmal mrtls o lciodloshbrre esinu,j ymolbst-vcsvilphn atehiit 'e,
# ae w? uet opinnfnhedldsaabbiugoid.vthp dsmyas  ll yth
# ei
# enb ,tr
# ulpoeiaenjvwavc  sw  ne  e,da ,ru m brn'wm etoesssm,t   gfb,-uknnt ollionirsrd foonlgceagllwgouue woks vo gle   ewd. rtsafefanot rsiokayouh
#
#
# ----- temperature parameter: 0.75
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
# see e anos
# s e  aaalo ret yhee ai na alldd- nn eee, teoh   ao hoyte mm   rwbsei  w,lel tmtsa
# ot et tsw ot eeessa alt iaw s mio y rh tesl aa iea ehtoae  a y sitmnsa sl o  t   s eti es, faaa  ly  t odcb      caes n  s e
# ekscts y  taoodssl  tyy  io   nmi oolr tanoh   a al  e fdlgictytn nit  e atcwsoeao i  aia lpsrfs  h tso cltostd  oh    ahntdeeeeanease oaatlis  et i eoyaihlear ratilnecetlianeotsirea   ow,ud raaie tesdlat s  et   a
# s mt hrnu g
# hntinsnlae v   btpe sa tio se
# h  n a,ites eoaieiv  t ee t o dmlo  mlvi     a tiaeowr s aseis    i  an  asn  nilnyy  crs l n e  srld,d taei si o e  es,  te admtee tll  te e lw  d   oetehyi iam
#
#   oihf sr f  m  e rvcauweheo eiet  r    e sta e n   al n it o  d bioymmm e,oh nir e taco eisr oaaa eii oaheo ah  eeesr ti y iidseeeeb scm ne im de     eehyto ls
#  stdl 'cisnsaltite   aie    ore    w
# ogrtieeod ee treef g t,  ose si  saeiceo rd  u r stn  oua e f t noeiy
# ry  t  o  hth     o    e o s rdl e   oa t   al  a    iirli aa   ms  t tuw e  ilem    o a   iclao   o  ag   ,teo   g r  ade  e ya         s  le ans an'
#    aeele i  roeaos el
#
#
# ----- temperature parameter: 0.25
# ----- Generating with seed: "shall i compare thee to a summer's day?
# "
# shall i compare thee to a summer's day?
#               e  e      t                 s     e            e   t          at       o           n    e                                                         a                               e     e       a      a        a  a      l                          a                                                                 ae          e    g                   e                            e              t                 e     t                               n          e                                              e           a   e      es  o          t  i              s    e                                                                                             s i           l                  l            e a      a s                         i    e                 s          t       s                                                    t      a      e           e                         e        e          e                           a    e aa  t            e       e                          e      e                            t          e                                 t       e   se             e a   e                     h       a                               t   o  e                t   i                    e e      a o                                        e   e ea         e                                          s e                       o                       t              t     ao     t                      i        s                 s                                                                      o                 e  r          e       e     t                                       eo           t               e                                                  e                  e                   e             t  e s        a             t       e         a            e     e a                                                                         i    e           e             e           s    e                                             e    t            i   d e                           e                 e            l          e                         e               e                      e                   a                 e                e       at                               t a              e                         t   s       e                          e                 ei         i                                       e       t t s               e                         a               e   s                                 e                                e  a             e              s              i              s      e   e   e                 e e                       e     e                        e  t     e              e  a  e                        h        e           l            te                          tt     ee  e     o                                                                             e s                                     e                                               t      e            e        e               o  e    e    e                          o                                                    l                       e                         o                                         s  e            o                              i                            ei              e   ra                 e                 l    t  a                i      a                                  i            e                                         t         e   e     e                             e                e        e       l                   a       t                           es e      e                         n              s                                           e     e              s           e      e                   o                      e                                                                                      i   e    t o            e    i           e                a                       e e               i s       ...
#           e           t                s   a   oh                       a          e                          e                                                e           a    e   e                    a       e                e           e  e                          a          r t                                                       e           a                 e                             e      i           e                              a                         t e     e                                 e            e                                        e      e         e     o       t            r                    t                                                    e                 e                i        e e                 e   o      sa                                                 e                  s                        la      e   t ee  s                    s                                   a                          ee e             s                             e                       a       a                                        e   d            e      s        t e            a              a                             e a                     a                          e     e e           t  a                   t   s                           a  ie                                   e                                 e    s                       e et   e         e              e             e             e              s                         e       s                                  e                                  l  e               e            t          t          e              s    ae  e   i                 i                                                            e      e          s                  e  o             t   e        i           e  a      e        t                         t           i          e                        n     a        s          e                             t    i                  i   e                              e          ee e           s                    e  t         i   e  i          t                                        e   a s          e           a  t                                    s                                           t                           t                           e                              ee a o                          e                              a    l        i              e    e                                  e    e              a          e               e                          a                       e        e                aei i                        e   t    ee                    n a  e       l s                         oe                          lte    e                          e             e                                          e                                                    t         t                   a                                            e                             t       s         t         at           t      a         a                   s i                      e      s          a e          ee             t            e     t                               t                      e       t                                                    e                 e                                                   e      o                     a   t               a  a           a          a                                  o                                          a  ne                    r   a                                                  t     e                      e         a                ta   e      t  o          e       l    e                   e  e        o                                      i       h     e       t        e                  e      r                 e               e            s e             i oe       e e  t t          i                                   e                                              e                     t            ...
#                                  a   t                                                 a                               e       e              i   e    eei    t                                     l                                   n                                                    e                                t         e                                           e                      e                  ee               e          t                  t     e                         t                                                     e           n                    e   ee      e    a       t          t                           en  t               e                    e                             t                      ea    a            et          e s s         e            a       t                                              s               a             a                    s                           e                                e    n                                       a  e                             e  e     t         e   e                                   n                                               t           e               t          e            o                   n      e    e s              eoa           t  s      e e   t           a                            t           e       e                             e                          e e                     a                      s e            e    e       tt                                                      e                     e t              a                                                        ra      e    e                      i                             e  a
#                 t                t         e                        e      e       a    s               e                                       t          e                  s      a                      e                                                                                   i              e                 e  e       ee              a  o                                   a           i                  s  a                                        s         e  a  o          t           e   e            e                         e   a                                                                       t        e                                                          e       e          o          t o n  n                    e            t           i         s             e e         e                                               i            e    s               e                 e           t                                   e       s                                         e     e            t          e         a                           e e a             e                   o         e                  i        t   t                                t             e              a                     e                                  s                           e            s                               e se             t e                   e             e                                               ee                                                          w         s         e                           se     e     s        e     e                                 e a              o                e          e                           e                                                             s    ee              a                    e     t       e             a                  e                s                  e         a      e            e          s                 p t   t     n  a             e     e  e                                   e   t             t                        e                          ae                     t                 s     t                                  e            es        n                          e         e     e                            r     e           s                                        e   s       e                                           o          s                                                                 a              e                     e           e            a                           e                    e a         e                               o                                 e   o a                    s           e                                     te   a                                           t        at        a            i                                  e       a     e  e               ea    s       o        e                  e             e      e                                e                                                                  e      s                 a         e     e                               e   te                    t                   s o     e              a  o      i         t       e   e  i   e                 t       ea e     t       t    e            s                     s               e             t s          a                    e                 l           i                    t            e                          e               s         e  a           e              e                               a                   e   t       e           ei   e    a   t    e  e         t   e                              e             e                a    t e a                s            e                    a                                                         ae                          e    e o                                           at     o  e           a             a    o                         a        r                  tt     e        o                 ...
#       t                t  o                     e               e      tr                               e      e                                                                       e     e          e                                               e                     e              e   e       e          e   e     a       e      a      e             e                 s              e  t              e e          a  e     e   e                  et    i    e                          e              t   a                 t        se            e     e          t               t           t                                              l     e                                  e      a                                               a          ei             h  e  e            e             e         e                                       t    e                                  e                                 e  e                                             a             ae                  o        s     e                e          i          e         s            e                         e      e                    e                     l     e      a                  e  e                              i te                                          e            o  e                     a               t        e           a                             e         t              t                   e       s         e                   e                                                        e                  n   a                           e            e                 a  i                            a       e        s  e          e                                   t ts e      e                                                         a                                e                                e        a                       e    e           ie      t            t                     o t                         s      t a     e             o a         e                            e                                            a           e                             s         s e                       e         s   o                             e                         e                  t            t          e       e  s    s            e  t         e            e                     e     i                      e         s   s   t e    a a    i  t   a          e                                                                       e            e  e  ee                                                    a       e                                               i   e                                        a     te    s             e                 i                   a        a                        e                                 e                                              o                                     e a          e                   a    a       t         ee                      s e                                   t       ae           i               e             t             r                     e                                                 e              s                                         e                     t          a                           e         e                           e     s                           e                                                          ee                      e  i e   h e    e        e                   a              e             i                      a           e     t              e rt                      e                  e e               e                   ee   t     s                                                                    e e       s                     e                      e              e            a t       e                       a                   e            e                                          o          t         e        a e                                                      e  e        t  ss        ...
# t                                              e                                                       e   a                           l               e                               t            h               e                              e                           e     s                                    a                        o                  e                        ot        s                           s                                      e   at     e                                           t                                e    i                                                                                        e   e          s       t      t       e        e    s                                     e     e                                  t       e                       t                         a                               e             a                                          s                e  e    e             t e   e                      a            i   ee                                                                                                                                                                           oe                           i               e                  n        a         e              e               a       a       s         t     e e              e                            t       e                  l    e         e       a                          a                            e     s                                   a                               e       a    e     s    i s               t           a e            e      h              t    ot e                     e            e            e                                      a  i          t        o            t       t                  s                                             e          i             e    e he                                                                                              e               e                         o                                                                                                     t     e                    a                                     i  s      e                      e                                             e         a e    l        a         s     i                                   o         ee        t t                           e                   o          t                                                                                     e             t                                           a        e          s              a     o         s          a                s                                                        t   e                   e                    e   t          t         a         a oe               a    e         a t         e   es    et     l                      s             s                                                                                          s     e    a              l  e     t    e        e           e                                        t             e      it    e  i                        e                    ee   e            e                                  a                    t                       e                                              a         n                            a     e                                  s   e                  e    e   a                               a  e                 e a         e                  s           s        t         e       l            e                      t         e          i            t        e                                                   e    e                     t     n                  a a          a               t              e    e                              e                                  e                               a                                             a       t               e e       e s                            e                              ...
#                 e          e   i              e          e a              e           ne                   e             s                             a a                             t   e    e                t       i                       s  e                    d                 e       t        s                               h e        i            a              o  a    e s       e          e                 t               a  e                      a     e        t           s        a               a    n           t                            e  t            e   t                      e                                              e                                  s                     e            e   a                            e e   tt   e        t e e                 e                                s             s                 a                s     e                     s s e                    t             e                   t a                                                  t                                                                              ih                                                                              e         a                                             e                  s             i                                o               e                                                     t                   t        s                          e                                             e                            e                       e                 e    e    t                            t   e         tt                     s      s              e                s          t          e      e      t                 e  a                          a         ap         e       soe          st i                                                                                                            e     i       t                                    a                       i         a                    a                     t  t        te           o           e               e           e e  i          s                    ee                         i  i  t         o e     ea   s                                o                                       t             e   e                       e     e                    ee         t                       t      at  a         a                o        t  i                    a                             r                    a            e           e               e         o               o                         t     e                  t      o            e                     h               e  e              e                            i               s a                              a    e                              t              e   h     et         l   s                 e         e       e                e          e           e    a                                 e               h              e             a            r                          e                         t      as                  t                           a  ee                                                      t  ea                            st   e                                 i  o              e                                                    e    i                                         e                  e          e                   e                                                                              e   s    o e           s                e         s        o      e             e                                             a                     a         e            t                                  e                                     e                a                          y           a t     a      e t                       t          e   e   s t   e ee          i                       s                      s           at                     t  l t        i                        e   e a     a   ...
#               t i           e  e     t   r                 e      a             i e                       e        i    i        ee                                    t      e     a      e                a            e a       e   t s                              e    e                 s                                 e        t  e                                         e                   t   e               a    t a                                         o                 e       e       s                     a     n e                      e    h                t                                        e    a            a             e     a              o    t   e               l e   ra      o                       ns       e            e   s      e   i          e         s               he e            s          e             e       e  e      t                          i          e            o  a                       a          t          o      t                            e               e  i                      e                   t                                ea e            ei         l         i                                            a                           e                  e    a                                                a  e                 o              e                    e                        le  e t                                  t          a    o                                                  t  e               a    s    i   e                              s    a     e            t             e         i                  e        t              e       a              e      s o a s                    e                 s e             e         e      e s                             e                     e                  i        s e                       a                            t         t      a                                                                          s                               t                                         a    i                    a     e                                   e     e         s      e                e           ae                          t     e e              t                                                     e    e           i             a                      t      i  t is                            a                                    e         t                 s o     o                                      t      e                             e          e   o   i               e        e      e                    e              s    e                t                 a   e                                    s                  t       a e             t                                               e        t                           e                                                    t                                              s                t            e                 t t             a                             e           t                  a                ee   e   te                                       e        td                a    o e                    a   t                                                                                           t                                   a   o                          e               t                   e                              e e            e             e   e      s   e                              s         e    e   e      n                    e             e    t           e  s s                             e    s                                e o        s                      a                   e   t               e                                                 e     e                                   n  e    e          e                                        i     s                t                            e  e                 e                                          s     e                                            i     ...
#        e  e    s      e             e                s                            e              e                                e              o      e                    s      t                                        a                                                e                       t                   s                       t e    a                                      e i e     a he   e   t  e       e  a   s e           a   e          t                a                    t       e                s             e         o     s  s               t         l                           e          se                                        e            s                                                      e                              te                       t                                 t                 a         a       ee             l                                                e  e               e          i                   t          i    s      a                                     e        a    l                          a   a         ee e             e t                                                                                       e e    s                  ts                                     e        e o    e                 e                             e       i    i s                      i     e    h           s       s  s    a                     e  e                       e       t     s   e          e     s                                e                               o    eo   e t                      o e                  l              l                                     e        s                    o                   a      s      n                                                                                     t  e        a       e               n  e   ae                                    o                          e                     e                     e           e             o              e        e    i                     a                      ao         e                   a   i           t                         e                                               e d            s                                               i                e                                                                        t  a et          e            t                      e    e                e                                             e             e   e     e              e          e                        t                 t  ae                              e                                        i        at               s                                           e                                         e                                         i                  a   a                                                   i     e  a                         e                                   e  e                                                                  a   a    e                        e                                      a      n    e         t                  e                       i    s                e        t          t    e              e t                              e       e                      es t            e          e       e     s   t      e                                  a                      s         t      h       n                       e   i                 e           t  i           e                e                 e               e                                      e                t    e e                            aa                      e          e                t  n                                   s                       ee                        ee     e              c                         a                          t                                                                                                 e     t                              s                          s    e             e  ...
#    t                         e       e        e                                                n                        en   ee                          ee  n    l  s      t         t  e    s              e                                                       e      e        t                         e  e                ea          s                                      a                                              e       e       s                       e l           t e   ee                 t                     e                                            e                   e                                     e      e        e         a                                                  a  e     a                            o      e         e e   s                      e  t   a                             e     e           e  tso                       t                       e                                     e       t  e   o      a              e                e                              s    e              i          o              e                     e                               i                   s  e                                      e     e          o e          a  s       i                         a                     e         o             a              i            r  e          t                                                                               e                                                            e                 e                                      l e                                e      h  t e              i          o      e   te                                          tt           e                        e    e       a e             se                                        e e      a                   e                 e                                                                                                n          e      i            e      a                                      t                  a                   se                                a                            e                                    ti                          t   i   e t             e      a     e e                                              e a             e          e                                               e  a       t             i      e               a      e              e             lh                          t                                      a        o                e  a                     e   e                                                e                     t   e                                           s                  t e e                                                                               a      te                                                                       e   e       s            t           i                           e o e     e                  os                    e                                          e  t ee                                      e                   e             e                                                   e               e      a                                                                         e                 s                                                                          e                       e              e        t                                    i  e   e             n t                         t  e     e               te s     o                      s      o                  e                         e     e                                                   l                     e           e  e             o                                e              t              t                           e                       ee        e      r ee                 a  o                       i                a                            e n                     aa e         o          e  e     t                e     o   o                                ...
#     s     e             i    e          a                       s                              e                   e     e                      e  s                e                                                 o                                      e         s               r                                         s        se         t    e        e                      n                                    a    n             e     e                 t ti                  e   e              e                                        ee  i ie                                     s                         e      l                                     a        s   t                             e                             e                   a n          t                   e                                              e   l      se   ee                              e                     o             t   e         e  a s             s        t                                                                             t e                                                                                                    t         a  e      a                                  s   e                  a                 e                            e       e   s          a       s     s       t      n      e              e e                                                                       e          n         ni s             e       s                               e     e  e         e                     t     e                                  i                                                     e                  e             l                          a     t     e             a                        e                                             e      e      e                        t   e         e                        s                  n          l            e                      t   t     e e                  t        e     t               i                            e       e t                e                                             t           o                    a                                   e         i                  o   e                             e   o      e               a                       e                      e                  e   e      t  t  r      e       t   a       e                       e                   s  e                                                      e   e             e          e                                         t                                 a       e      ee                        t                                   t e                        t                    e      l                t    e                                                    e                    e                                     s                                       ie e   e                                 t                                   l e                                                              h                 e                                                         e           e a                   ee   e      a                                                                    e                                                   t                                 o  e        e         e              e                e                                                    i    e                    a          r                 e                   e      e                                                      e                     e           o  s                                  e                                             t     e                                                          e     t         a     i                                               e                                                                 e             e        a                             e                                    r                                    l  e e e              ...
# ...
#   t estt   eet          ee          e   e t e   e    a  e  e ee s ei   tt t    e  e    e                     ett   e         s  i  i       te      e   te      s t  e     e              i  et      e  t  t   e    et    tt      e     t     i t         s tt tt   ats      t     e t t  t         a i     t  a                    t        e          es es          e         e  ee s    e      e    ae t                t  en tet   te     e ea      t  e e s        t   t   s ese  t t  t       s  e  e et     et  tt t  e       e e  a    es   a  t  e  t               ett      tt  e      e             s e             t  t      e       e   ee  ts  t    t  t e  t t t   t   t t  t e        ea       e     te  tt       e  t  ee            e   i  t tt                  at           t      h   e  t e   t  s          t e  t            e e         t    e e      t    t    s    s      t  te   t i   e st      s       t t        e  eeet               s  t      satt e t      e                    ts       e     e  t  e t   ee   t t     tse      i  se e a       tt    t   e   t    e  t    t    e  e   e    tt   t  ttte      ee  e  t  ee  s  s    e se          e   a        e h   ss         s   t t t   te   e e  i   t     ati s    i t  yt       te      tee t a       s t                       e   tah         st            attet  t    t t i  ee    t   est it e      t       e        e       ee e  e     t e e       t       a tt h     tt et      t   t       ee       s t      tet  e    et             t s t t  t eta    e     st  s        eee     e     t e      te               t       t     e  t e  t       ete  e  tt t      e at   t t te  te   e       ee st ee  t     te   itt  t        t       e s e  e  e    t  et    e        s
#    e    h  e   t    a     e  e       est e t     e e        t e t    te te  t   e      as    i        e    e et       es          s    t  tt t        e        e     a  t          e   e     t  t   ea    i e    t   e       t           t    t  se a ee   t       eee  e    t      e         as    t e                       t    t   ee          l t      e          t    t  ee  s    e e e      s e  se        a    t e       ee     t s  aa e t     te t  tt n ee         ee    e t   e           ete  tt   e  s  e  t t    t  t tt    s        e     e      t   e         t  te          t e             e e t        e    e   e     e e    i a     e      s t   e          t e   e       e     t       s    t te      eete       e    et         r e e       t y      e   te      ye     i         t      te   t     tet       e          e    a  ee      t en       rte a  e      e a ie e          s  t       eet s  t e             t t       ese  a                   s  e       et    s e a e   t e  e t         t te     t  t e  e et    r        s   ee e         e      e   t        et    t      ee                    a t   t               e                        a    t       t te   e        e  e  e e  e   t        e  e            st   e            s e   tt        t eatt e          e t                     e     e       t  e e  t  t   e  e  tth                         ee   a    t        tt tr   e e    t  ettt     t t e   t  e   i  t           ett            t   o        et  s             e       e s             te   e    e   e  aeet      e e t s   t s  e   at t     s e  ete   tt  t ae  it  ee          t  e eett  e  a   t    t t   t    be             t  t e    e    e     e  s    es ee e  ee        t  t             tt et   es       s        t  e      t         e           t   h    ee   et   e       t    t e  e  e    t  a  t   t e          ttt    e       e       ee   e     t  te     s  n e it   e    e  ee    te     ea    et           teth       t                e         h  e      e  e       see    t         e  tea                    t      e  t et       t    e     tee          ts  t     t t e t       ea   et        t s        e  t        e    t  ee  t t     e        s  ee tt  a    stet   e           t e e s     ee   t     e  tt    t ee ttt    a      e     tt t         ts         e  e     h       t  t t   te  t   t    et      ea      e  e e et e       e  e   t  h ta e      t             e   te               t     ae e          te e    e    e  e    e e    t      e t   e e       t                           t            e  eet t     e        t   a e e              ae  ts e e     t t  t  e        t  e         e e     e     i         s e ea    te   e  s      t         t      e     ts   e t e   e tt  e  et see    et           t      e  ti   e  t t                 t    a      i   ttt   s     e et  t        t tee t    tt t t               t             s            t  s              e   e    t et     s       t ts     e       ee                ttt se  t t                 e       e t t              tt          e      tt  e       l  e        e   e  t   e   t    s t   t        e       e               stt e      t eee         e    e t t      e    t     eit e   s  ae      t              e  e t et  e           t t    t      t   t        e   et   t  t t t et     et e       e    ae    t  e  e s        t   t  t          t   t e   a  ee  e   ee      e   e t   t    i s          t  t      e    t  t          ee   e       a     t e e  ts   s e                s  t s    e e          t           t s  nt           te ee  t           e    eht    et   e t   e   e t  n    t           t         e     e  ett    e    t       t       t       t   tee      e    et       at              t   e et   t   e   s   t         e      i  t    a   e  e    e    t   t       e               s     tte     t t e         t   e  et     t   e          eetee tee   eet   see      t       t e   t  t            ee   e            s st ts   t      tet t    s  s t e      s         et           e   e    e  e  e           e     e     ...
#       aee   t           ett       ess         i  t  s  at tt    t t    s   e e  e e  s ae   s  et        e t     t      e     t e  et e ts   t n     t   t t s   t t      tt  es  t t       e   tse      t s          t   e    e           ts   t t e        t      e  e       t              tti            et        ,   e        t        s tei eet         t ee       t i  e  e       t e  t    ee    t t          t t     e t        e ts     t      e       e   te   ts   e      e    ts  e    tsate  e            e       e      te  t      t     s   t  et     tt         st   et   a   t  e     h    t  t t        t      t  e    e       a        e  t t        es   e    e  a        t ea  st        t   t   t e  t s           ee            h   aie  s     i    ee  t    e t   t       e   e          e     t t     t     t   s   t   e    t        ets t    t     e t   e  t  s ee         ee   ee   e  t  t       t     e     e  re e         t      t t  s    s              s  t         e      a e             i   s       e         o   tt               tt  tt        et       t    s t        h                   u   e    a          t    at   t         e    ee    y          t    t             t     t        ee  t   ts  t    ae e   tt     t     e   e       t    e          ee             a ,t e                    t   t e    s   s     t    e     e      i ete   e  t e e    e      e     t   a     e   tt       e   et e e e         t e t s   se e  t     s      i       s tttt t       e  t         t                          t    e e  s  e                 s   e   e s s teee   e    e    e     e  t ettee e      t   e       e  e     e      e            t  i   t  e e    es              t  b et e    eie           e  s e  t        ete   t   hta           a   t eh e  t     e    etsss  n         t i       t t      tste     t   e   tte      ee  s   e a    a   s     t e          s s    t       s        te et es     e     t tte      e h   t   h          i  t       tt      t   e          s e t   ee t a    ts     t t     ee s         s     e  ee t ttt    e    se e ts          e        e    n      t   ee ee   t t    t  t    s  h t e    s ee   ts              t     e    ee t   s  s  ee  e     se e  tt t e t    e    e      ett      e e     t   e      e a          e   e                                 tt              s     et       t    t   tt t     a    e    e   te                t ae      e t e e             ese                e t    t      t           tt          e    a           s         t  h e   t    ee   t   e   t tt    ta        e     e        t          t      e         tes      ae  s      t    e    t    et            a   t    s   et  ei    t e    ete ee   e             t et                   t      t   e    h    a      e     e t  t    eet       s t         t  ate        e  ee e e            st t       t   s   t t a eati   s      s    e tt   s t  t   e    te   t   e  e      t            e  t     ee       ee    tt  t et  i             e     ee          es    te       t  et       i     ei      ett t   e        t t   te  tt          t t t  ea       tt e e         e   s     s    ee     tt            ee          tt                   e e  t s        e  t           s   s         se        e  t  e   t e     s    e       st      t t t e  t    t      s  e s e tt   ee e e t   et   e     t t     tt  t  te    t   e                 e    tie  s      e     t                     te t teeie t t    ee      tt    te   ese    t    s       t         tee    stt           ea  eet   at                e  e  t    s  eet t e     t    e         t  e  tee           t    t         e      t s  te  te e   t  ee e      e s e       t    e    e       e    e    t    tte  s t   t       t    s      s            t         ee   e          te         a        s     s  e     t      a    e att  e t   e                t t s  s         e e  t   e  tt     e        t e       e s          t   e     t    s            e   e t       e   e tt       t   a e   a   ts    t    e  t  t  t         e   t       t               e t t        ...
# t  ea  eeae           t ie    e t   ttt   at  et     e           te t     e  t   et       t     i      e       ts    a   t     e s eet          e  t   s   e  s i    i tsea e    s        e  tt  t et  t    t      tt  si           t      ete          e s    h        t                ee  e s   e s        e    t           t             e s t    e  t t      s       e  tte   e     e  t       e te ee     et  e sse        t   a et     t t      t             et    ei e    e        ee  ee e a  e  p          e  te  s ttta t      it             ts           ee           ete e  tt e  t hs      e   t   t       te s e        e    s       t       s             et       e       t  t       t     e   e      te    e  ee    i  te t   ss    e    e e   t         t e tt         ta    at   e  e      i        ee     at      t  t  t  t                               e  t         i  t t e      t        i   s   t         u te              e       e t     e  e e   e    se    t  e            e  e      ae   e   e e  e             t  t   te   ee                  r       e        t   e   i              e   t  te e t    e  e e  s     e        e  t   te  e   t  t  s s e      t    a     a                    e             t    e    e    e                i    en s i    t  s  e  es   t e   t  tet eeee    t         t      e i i       e   e   s  ee             t t   e      t e  ie e i     s       t     s       es   t s  e          t     e  e ee           e               t      t                  s  e      t  e  sth   a    eeee     t t      a      et   t     e   tet   t      t se e      a                       t        e t  t t tt       t t        t      e       ta  e  s e tt    e t t t ae h i    r e    e ee             t         st              s n t e     t e      a       ee  e  e   e     tt  e      t     e   t    e   t i e     h      a          e    e  e      t   a  tt   t  t         e    t     s       t          t se   a  e  e    e          t           e      t    t       e       t   tt t   t   t e             ai     t   e   a     e   t      t   e e       se e             e  t   et        ee e te   se         t         eaa   t ti s   e             t    att    s  t   te  t e      t    t e  as te   e        e         ee            e    t   a e      t  es   a       e       te t           e     se  t    e     s    se t  t   t              te ee  i  t    et    e   at t    e ht            t            t         et         ee   ee       t e et t     t     e        e    a        t e   s t t   e    se t         t        t    s   e  s      te         e tt   e    es   e      e  e  t  et     e et  e               h          st    tt  e            t  t   aeee  e   t  e  e e  e    a      t        t     t s  t         e     s                  e     e          ae  e e     e te              ee    t  eet   t     e  e    t       tssa  e t  t     i    e  e         e       e a  t t      est  t           a      t     t         t s       t             s    e      e                 t    eie     s            e      e     t  e e et    ee e   ee                         e        ee   e     e  e   e  tt         t    te                  t  e ie te ee                 e h   ee     te  e      t te e  t       t t    a   tte e  e  as        t e t t   t         t         e   t  e t      t                 e t  te s t ta         t   tt    e  e           s                ss  a   t ete    s       e                   t                     e   t e  es t      a  a s           t et  t t  e  t   tee e stet te       e teit    et t e    t     t         t ee  e ee     t    e    t  t   t   i      s t    st  e    t      te    t       see   t       et e    e t        te         e  e     e t    a      e est  et  e           e  et   s     s te          t      e   e            e        t  t  t       f              es  e s  e  t e   t    e e           e         e         e e          et          e         e   et     t e    t          t e  e     ss  e ett      s     te    e     t    a  t           s        te    e  e  t   ...
